# %% [markdown]
# <a href="https://colab.research.google.com/github/Drat47/Dharmesh-/blob/main/chapter_appendix-tools-for-deep-learning/jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
p = " heloo how are you"
print(type(p))
# Out:
# <class 'str'>

# %%
p = 12345435324834783274029999999999999999999985345435
print(p)
print(type(p))
# Out:
# 12345435324834783274029999999999999999999985345435
# <class 'int'>

# %%
p =3.01443444444444444444444444444444444444444444444444444444444444444444444444444444443543534543230989844444444444444444444444444444444444444444444444444444444444444444444444444444
print(p)
print(type(p))
# Out:
# 3.0144344444444444
# <class 'float'>

# %%
p = 3.45 + 4j + 908907897987
print(p)
print(type(p))
# Out:
# (908907897990.45+4j)
# <class 'complex'>

# %%
p = [3,5,3,2]
print(p)
print(type(p))
# Out:
# [3, 5, 3, 2]
# <class 'list'>

# %%
p = [3,[78,34],5,3,2]
print(p)
print(type(p))
# Out:
# [3, [78, 34], 5, 3, 2]
# <class 'list'>

# %%
p = [3,[78,34],"h",5,3,2]
print(p)
print(type(p))
# Out:
# [3, [78, 34], 'h', 5, 3, 2]
# <class 'list'>

# %%
p = [3,[78,34],["nbjbh"],5,3,2]
print(p)
print(type(p))
# Out:
# [3, [78, 34], ['nbjbh'], 5, 3, 2]
# <class 'list'>

# %%
p = ["hii", "sfd"]
print(p)
print(type(p))
# Out:
# ['hii', 'sfd']
# <class 'list'>

# %%
p = (3,5,6,8)
print(p)
print(type(p))
# Out:
# (3, 5, 6, 8)
# <class 'tuple'>

# %%
p = (3,5,6,8,(4,6,2))
print(p)
print(type(p))
# Out:
# (3, 5, 6, 8, (4, 6, 2))
# <class 'tuple'>

# %%
p = (3,5,6,8,(4,6,2),"df",8.7)
print(p)
print(type(p))
# Out:
# (3, 5, 6, 8, (4, 6, 2), 'df', 8.7)
# <class 'tuple'>

# %%
p = range(7)
print(p)
print(type(p))
# Out:
# range(0, 7)
# <class 'range'>

# %%
p = range(65,-37,34)
print(p)
print(type(p))
# Out:
# range(65, -37, 34)
# <class 'range'>

# %%
dict ={"name":"dha", "age" : 23}
print(dict)
print(type(dict))
# Out:
# {'name': 'dha', 'age': 23}
# <class 'dict'>

# %%
set = {"sa","sdf",}
print(set)
print(type (set))
# Out:
# {'sa', 'sdf'}
# <class 'set'>

# %%
set = {"sa",34,"sdf",}
print(set)
print(type (set))
# Out:
# {'sa', 34, 'sdf'}
# <class 'set'>

# %%
set = frozenset({"sa","sdf"})
print(set)
print(type (set))
# Out:
# frozenset({'sa', 'sdf'})
# <class 'frozenset'>

# %%
set = frozenset({"sa","sdf",23,3.54})
print(set)
print(type (set))
# Out:
# frozenset({'sa', 3.54, 'sdf', 23})
# <class 'frozenset'>

# %%
m = True
print(type(m))
# Out:
# <class 'bool'>

# %%
f = b"hiii"
print(f)
print(type(f))
# Out:
# b'hiii'
# <class 'bytes'>

# %%
f = b"23"
print(f)
print(type(f))
# Out:
# b'23'
# <class 'bytes'>

# %%
b = bytearray(b"hello")
print(b)
print(type(b))
# Out:
# bytearray(b'hello')
# <class 'bytearray'>

# %%
b = memoryview(b"hello")
print(b)
print(type(b))
# Out:
# <memory at 0x781f3f8cde40>
# <class 'memoryview'>
