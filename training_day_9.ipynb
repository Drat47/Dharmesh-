# %% [markdown]
# <a href="https://colab.research.google.com/github/Drat47/Dharmesh-/blob/main/training_day_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#sets
order isn not presemt
indexing and slicing not work
unique values
mutable
heterogenrous lements are presne t
frozenset is immutable
set was introficed in the 2.3 version

# %%
set1 = set()
print(type(set))
# Out:
# <class 'type'>

# %%
set3 = set("Rahul")
print(set3)
# Out:
# {'h', 'R', 'a', 'l', 'u'}

# %%
#does not support inmdex
set3 = set("Rahul")
print(set3[4])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2188476689.py in <cell line: 0>()
#       1 #does not support inmdex
#       2 set3 = set("Rahul")
# ----> 3 print(set3[4])
#
# TypeError: 'set' object is not subscriptable

# %%
#way to iterate
set3 = set("Rahul")
for i in set3:
    print(i)
# Out:
# h
# R
# a
# l
# u

# %%
set3 = {1,3,25,54,64,523}
set3.add(5)
print(set3)
# Out:
# {64, 1, 3, 5, 54, 25, 523}

# %%
#repetitionn not allowed
s = {1,3,25,54,64,523}
set3.add(5)
set3.add(5)
set3.add(5)
print(set3)
# Out:
# {64, 1, 3, 5, 54, 25, 523}

# %%
#update
set3 = set("Rahul")
s = {1,3,25,54,64,523}
s.update(set3)
print(s)
# Out:
# {64, 1, 3, 523, 'h', 'R', 54, 'a', 25, 'l', 'u'}

# %%
#remove partivular item
s = {1,3,25,54,64,523}
s.remove(3)
print(s)
# Out:
# {64, 1, 54, 25, 523}

# %%
#pop
s = {1,3,25,54,64,523}
s.pop()
print(s)
# Out:
# {1, 3, 54, 25, 523}

# %%
#unique element in the string
str = "be the change you wih in the world"
s = set(str)
print(s)



str = "be the change you wih in the world"
s = str.split(" ")
set3 = set(s)
print(s)
print(set3)


s = "be the change you wish in the world"

unique_words = []
for word in s.split():
    if word not in unique_words:
        unique_words.append(word)

print(unique_words)


s = "be the change you wih in the world"

unique_words = []
for char in s.split():
    if word not in unique_words:
        unique_words.append(word)

print(unique_words)
# Out:
# {'e', 'o', 't', 'w', 'h', 'd', 'y', 'i', ' ', 'a', 'u', 'r', 'g', 'n', 'l', 'b', 'c'}
# ['be', 'the', 'change', 'you', 'wih', 'in', 'the', 'world']
# {'world', 'wih', 'the', 'be', 'change', 'you', 'in'}
# ['be', 'the', 'change', 'you', 'wih', 'in', 'world']
# ['world', 'world', 'world', 'world', 'world', 'world', 'world']

# %%
#get the length
s = {1,3,25,54,64,523}
print(len(s))
# Out:
# 6

# %%
#the comnstrucrtor
thisset = set(("apple", "banana", "cherry")) # note the double round-brackets
print(thisset)
# Out:
# {'apple', 'banana', 'cherry'}

# %%
#access the set items
thisiset = {"apple", "banana", "cherry"}
for x in thisset:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
#item present or not
thisset = {"apple", "banana", "cherry"}
print("banana" in thisset)
# Out:
# True

# %%
#add item sets using add
thisset = {"apple", "banana", "cherry"}
thisset.add("orange")
print(thisset)
# Out:
# {'apple', 'banana', 'orange', 'cherry'}

# %%
#use the update methofd
thisset = {"apple", "banana", "cherry"}
thisset.update(["orange", "mango", "grapes"])
print(thisset)
# Out:
# {'apple', 'banana', 'grapes', 'mango', 'cherry', 'orange'}

# %%
#add any iterable
thisset = {"apple", "banana", "cherry"}
mylist = ["kiwi", "orange"]
thisset.update(mylist)
print(thisset)
# Out:
# {'apple', 'banana', 'kiwi', 'cherry', 'orange'}

# %%
#remove and element using pop remove discard clear del
thisset = {"apple", "banana", "cherry"}
x = thisset.pop()
print(x)

x = thisset.remove("banana")
print(x)

x = thisset.discard("banana")
print(x)

x = thisset.clear()
print(x)

del thisset
print(thisset)
# Out:
# apple
# None
# None
# None
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3915014775.py in <cell line: 0>()
#      14
#      15 del thisset
# ---> 16 print(thisset)
#
# NameError: name 'thisset' is not defined

# %%
#pythm loop
thisset = {"apple", "banana", "cherry"}
for x in thisset:
  print(x)

# %%
#join sets
set1 = {"a", "b" , "c"}
set2 = {1, 2, 3}
set3 = set1.union(set2)
print(set3)

set1 = {"a", "b" , "c"}
set2 = {1, 2, 3}
set3 = set1 | set2
print(set3)


set1 = {"a", "b" , "c"}
set2 = {1, 2, 3}
set4 = {"as",23,"gvr"}
set3 = set1 | set2 |set4
print(set3)

set1 = {"a", "b" , "c"}
set2 = {1, 2, 3}
set4 = {"as",23,"gvr"}
set3 = set1.union(set2,set4)
print(set3)
# Out:
# {1, 2, 3, 'a', 'b', 'c'}
# {1, 2, 3, 'a', 'b', 'c'}
# {1, 2, 3, 'as', 'gvr', 'a', 23, 'b', 'c'}
# {1, 2, 3, 'as', 'gvr', 'a', 23, 'b', 'c'}

# %%
#join set and tuplke
set1 = {"a", "b" , "c"}
tup = ("as",23,"gvr")
z = set1.union(tup)
print(z)
# Out:
# {'as', 'gvr', 'a', 23, 'b', 'c'}

# %%
#intersection
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}
set3 = set1.intersection(set2)
print(set3)


#intersection
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}
set3 = set1 & set2
print(set3)


#intersection_update
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}
set1.intersection_update(set2)
print(set1)


#intersection
set1 = {"apple",1,0,"banana", "cherry"}
set2 = {"google",True,False,"microsoft", "apple"}
set3 = set1.intersection(set2)
print(set3)
# Out:
# {'apple'}
# {'apple'}
# {'apple'}
# {False, True, 'apple'}

# %%
#difference
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}
set3 = set1.difference(set2)
print(set3)


set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}
set3 = set1 - set2
print(set3)

#difference update
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}
set1.difference_update(set2)
print(set1)


print(set1 & set2)
# Out:
# {'banana', 'cherry'}
# {'banana', 'cherry'}
# {'banana', 'cherry'}
# set()

# %%
#symmetric difference uodate
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}
set1.symmetric_difference_update(set2)
print(set1)

#symmetric differne=ce
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}
set3 = set1.symmetric_difference(set2)
print(set3)
# Out:
# {'google', 'banana', 'microsoft', 'cherry'}
# {'google', 'banana', 'microsoft', 'cherry'}

# %%
#python frozenset
x = frozenset({"apple", "banana", "cherry"})
print(x)
print(type(x))
# Out:
# frozenset({'apple', 'banana', 'cherry'})
# <class 'frozenset'>

# %%
#differences of fset in python
set1 = set()
set2 = set()
for i in range(5):
  set1.add(i)
for i in range(3,9):
  set2.add(i)
print(set1-set2)
# Out:
# {0, 1, 2}

# %%
#method to remove all the r=elemensts in the set
