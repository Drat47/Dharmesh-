# %% [markdown]
# <a href="https://colab.research.google.com/github/Drat47/Dharmesh-/blob/main/trainingday2_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list3 = ["apple","banana","mango"]
for i in range(len(list)):
    print(list[i])

i = 0
while i < len(list):
  print(list[i])
  i+= 1

#coprehenssion looping
[print(x) for x in list]
# Out:
# apple
# banana
# mango
# apple
# banana
# mango
# apple
# banana
# mango
# [None, None, None]

# %%
list1 = ["apple","banana","mango"]
[print(x) for x in list1]

newlist = [x for x in list1 if "a" in x]
print(newlist)
# Out:
# apple
# banana
# mango
# ['apple', 'banana', 'mango']

# %%
list1 = ["apple","banana","mango","kiwi"]
newlist = []

for x in list1:
  if "a" in x:
    newlist.append(x)

print(newlist)
# Out:
# ['apple', 'banana', 'mango']

# %%
list1 = ["apple","banana","mango","kiwi"]
newlist = [x for x in list1 if "a" in x]
print(newlist)
# Out:
# ['apple', 'banana', 'mango']

# %%
#python sort
list1 = ["apple","banana","mango","kiwi","baaana","Fat","true"]
list1.sort()
print(list1)

list2 = [34,567,23,78,43,]
list2.sort()
print(list2)


list1.sort(reverse = True)
print(list1)

list2.sort(reverse = False)
print(list2)
# Out:
# ['Fat', 'apple', 'baaana', 'banana', 'kiwi', 'mango', 'true']
# [23, 34, 43, 78, 567]
# ['true', 'mango', 'kiwi', 'banana', 'baaana', 'apple', 'Fat']
# [23, 34, 43, 78, 567]

# %%
def myfunc(n):
  return abs(n-50)

list2 = [50,4,567,23,78,43,57]
list2.sort(key = myfunc)
print(list2)
# Out:
# [50, 43, 57, 23, 78, 4, 567]

# %%
#case sensiruive sort
thislist = ["apple","bAnana","mango","Kiwi","baaana","Fat","True"]
thislist.sort()
print(thislist)



thislist.sort(key = str.lower)
print(thislist)


thislist.reverse()
print(thislist)
# Out:
# ['Fat', 'Kiwi', 'True', 'apple', 'bAnana', 'baaana', 'mango']
# ['apple', 'baaana', 'bAnana', 'Fat', 'Kiwi', 'mango', 'True']
# ['True', 'mango', 'Kiwi', 'Fat', 'bAnana', 'baaana', 'apple']

# %%
##copy list
list1 = ["apple","banana","mango","kiwi"]
list2 = list1.copy()
print(list2)
print(id(list1))
print(id(list2))
print(memoryview(b"list1"))
print(memoryview(b"list2"))

mylist = thislist[:]
print(mylist)



# mylist = list(list1)
# print(mylist)
# Out:
# ['apple', 'banana', 'mango', 'kiwi']
# 138052717241472
# 138052396967616
# ...
# ['True', 'mango', 'Kiwi', 'Fat', 'bAnana', 'baaana', 'apple']

# %%
# join the list
list1 = ["apple","banana","mango","kiwi"]
list2 = [1,2,3,4]

list3  = list1+ list2
print(list3)
# Out:
# ['apple', 'banana', 'mango', 'kiwi', 1, 2, 3, 4]

# %%
#append list3 in list1
list1 = ["apple","banana","mango","kiwi"]
list2 = [1,2,3,4]

for x in list2:
  list1.append(x)

print(list1)


list1.extend(list2)
print(list1)
# Out:
# ['apple', 'banana', 'mango', 'kiwi', 1, 2, 3, 4]
# ['apple', 'banana', 'mango', 'kiwi', 1, 2, 3, 4, 1, 2, 3, 4]

# %%
#tuple

thistuple = ("apple","banana","mango")
print(thistuple)


thistuple = ("apple","banana","mango","banana")
print(thistuple)

print(len(thistuple))

thistuple = ("apple",)
print(type(thistuple))

#NOT a tuple
thistuple = ("apple")
print(type(thistuple))


tuple1 = ("apple","banana","mango")
tuple2 = (1,2,3,4,5)
tuple3 = (True,False,True)
print(tuple1)
print(tuple2)
print(tuple3)



tuple4 = ("fds",34,True,"fdgrd")
print(tuple4)



#comstructor
thistuple = tuple(("apple","banana","mango","kiwi","laddo"))
print(thistuple)

print(thistuple[1])
print(thistuple[-1])
print(thistuple[2:5])
print(thistuple[-4:1])
# Out:
# ('apple', 'banana', 'mango')
# ('apple', 'banana', 'mango', 'banana')
# 4
# <class 'tuple'>
# <class 'str'>
# ('apple', 'banana', 'mango')
# (1, 2, 3, 4, 5)
# (True, False, True)
# ('fds', 34, True, 'fdgrd')
# ('apple', 'banana', 'mango', 'kiwi', 'laddo')
# banana
# laddo
# ('mango', 'kiwi', 'laddo')
# ()

# %%
tuple1 = ("apple","banana","mango")
y = __builtins__.list(tuple1)
y[1] = "kiwi"
tuple1 = tuple(y)
y.append("orange")
typle1 = tuple(y)

print(tuple1)
# Out:
# ('apple', 'banana', 'mango')

# %%
thistuple = ("apple","banana","mango")
y = ("orange",)
thistuple += y
print(thistuple)
# Out:
# ('apple', 'banana', 'mango', 'orange')

# %%
thistuple = ("apple","banana","mango")
y = __builtins__.list(thistuple)
y.remove("apple")
thistuple = tuple(y)
print(thistuple)


thistuple = ("apple","banana","mango")
y = ("banana",)
thistuple -= y
print(thistuple)
# Out:
# ('banana', 'mango')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-564253679.py in <cell line: 0>()
#       8 thistuple = ("apple","banana","mango")
#       9 y = ("banana",)
# ---> 10 thistuple -= y
#      11 print(thistuple)
#
# TypeError: unsupported operand type(s) for -=: 'tuple' and 'tuple'

# %%
thistuple = ("apple","banana","mango")
del thistuple
print(thistuple)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4217760919.py in <cell line: 0>()
#       1 thistuple = ("apple","banana","mango")
#       2 del thistuple
# ----> 3 print(thistuple)
#
# NameError: name 'thistuple' is not defined

# %%
fruits = ("aple", " banna","cherry")
(green,yellow,red)  = fruits
print(green)
print(yellow)
print(red)


fruits = ("aple", " banna","cherry","orange","tuple","kiwi")
(*green,yellow,white,red)  = fruits
print(green)
print(yellow)
print(white)
print(red)
# Out:
# aple
#  banna
# cherry
# ['aple', ' banna', 'cherry']
# orange
# tuple
# kiwi

# %%
fruits = ("aple", " banna","cherry","orange","tuple","kiwi")
for x in fruits:
    print(x)
print("\n")


for i in range(len(fruits)):
    print(fruits[i])
print("\n")

i = 0
while i < len(fruits):
  print(fruits[i])
  i+=1

while i < len(fruits):
  peint(fruits[i])
  i+=1
# Out:
# aple
#  banna
# cherry
# orange
# tuple
# kiwi
#
#
# aple
#  banna
# cherry
# orange
# tuple
# kiwi
#
#
# aple
#  banna
# cherry
# orange
# tuple
# kiwi

# %%
fruits = ("aple", "banna","cherry","orange","tuple","kiwi")
mutiply = fruits * 2
print(mutiply)

print(fruits.count("aple"))
print(fruits.index("banna")) # Changed 'banna' to ' banna' to match the tuple element
# Out:
# ('aple', 'banna', 'cherry', 'orange', 'tuple', 'kiwi', 'aple', 'banna', 'cherry', 'orange', 'tuple', 'kiwi')
# 1
# 1

# %%
##sets
#unordered, unchangable, and do not allow duplicate value

myset = {"apple","banna","cherry"}
print(myset)

thisset = {"apple","banna","cherry","apple"}
print(thisset)

thisset = {"apple","banna","cherry", "1",int("1"),True,0,False,-1,-0.5}
print((thisset))
print((thisset))
print((thisset))

print(len(thisset))
# Out:
# {'cherry', 'banna', 'apple'}
# {'cherry', 'banna', 'apple'}
# {0, 1, -0.5, '1', 'apple', 'cherry', 'banna', -1}
# {0, 1, -0.5, '1', 'apple', 'cherry', 'banna', -1}
# {0, 1, -0.5, '1', 'apple', 'cherry', 'banna', -1}
# 8

# %%
set1 = {"apple","banana","cherry","kiwi","method"}
set2 = {1,2,3,4}
set3 = {True, False, True}
print(set1)
print(set2)
print(set3)

set4 = {"abc",34,True,40,"male"}
print(set4)


#add items
set2 = {"apple","banana","cherry","kiwi","method"}
set2.add("orange")
print(set2)

for x in set2:
    print(x)
# Out:
# {'kiwi', 'cherry', 'apple', 'banana', 'method'}
# {1, 2, 3, 4}
# {False, True}
# {True, 34, 'male', 40, 'abc'}
# {'orange', 'kiwi', 'cherry', 'apple', 'banana', 'method'}
# orange
# kiwi
# cherry
# apple
# banana
# method

# %%
set1 = {"apple","banana","cherry","kiwi","method"}
set2 =(1,2,3,4,"orange")
set1.update(set2)
print(set1)



set1.remove("banana")
print(set1)


set1.discard("cherry")
print(set1)

set1 = {"apple","banana","cherry","kiwi","method"}
x = set1.pop()
print(x)
print(set1)

#pop does noit ake any argument
set1 = {"apple","banana","cherry","kiwi","method"}
x = set1.pop("banana")
print(x)
print(set1)
# Out:
# {'orange', 1, 2, 3, 4, 'method', 'cherry', 'banana', 'kiwi', 'apple'}
# {'orange', 1, 2, 3, 4, 'method', 'cherry', 'kiwi', 'apple'}
# {'orange', 1, 2, 3, 4, 'method', 'kiwi', 'apple'}
# kiwi
# {'cherry', 'apple', 'banana', 'method'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3043378773.py in <cell line: 0>()
#      20
#      21 set1 = {"apple","banana","cherry","kiwi","method"}
# ---> 22 x = set1.pop("banana")
#      23 print(x)
#      24 print(set1)
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
set1 = {"apple","banana","cherry","kiwi","method"}
set1.clear()
print(set1)

set1 = {"apple","banana","cherry","kiwi","method"}
del set1
print(set1)
# Out:
# set()
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3352203454.py in <cell line: 0>()
#       5 set1 = {"apple","banana","cherry","kiwi","method"}
#       6 del set1
# ----> 7 print(set1)
#
# NameError: name 'set1' is not defined

# %%
#uhnoin
set1 = {"a","b","c"}
set2 = {1,2,3,"b"}
set4 = {"True", True}
set3 = set1.union(set2,set4)
print(set3)

#join
set1 = {"a","b","c"}
set2 = {1,2,3,"b",True}
set4 = {"True", True}
set3 = set1 | set2
print(set3)
# Out:
# {1, 2, 3, 'b', 'a', 'True', 'c'}
# {1, 2, 3, 'b', 'a', 'c'}

# %%
set1 = {"a","b","c"}
set2 = (1,2,3,"b",True,False)
set4 = ["True", True]
set3 = set1.union(set2)
set5 = set1 | set4
print(set3)
print(set5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3384538360.py in <cell line: 0>()
#       3 set4 = ["True", True]
#       4 set3 = set1.union(set2)
# ----> 5 set5 = set1 | set4
#       6 print(set3)
#       7 print(set5)
#
# TypeError: unsupported operand type(s) for |: 'set' and 'list'

# %%
set1 = {"a","b","c",True}
set2 = {1,2,3,True}
set4 = {"True", True}
set3 = set2.intersection(set4,set1)
print(set3)


set3 = set2 & set1
print(set3)
# Out:
# {True}
# {1}

# %%
set1 = {"a","b","c",True}
set2 = {1,2,3,True}
set4 = {"True"}
set3 = set2.difference(set4)
print(set3)

set5 = set2 - set4
print(set5)
# Out:
# {1, 2, 3}
# {1, 2, 3}

# %%
set1 = {"banana","apple","cherry"}
set2 = {"google","microsoft","apple"}
set3 = set1.difference_update(set2)
print(set1)

set1.symmetric_difference(set2)
print(set3)

set4 = set1^set2
print(set4)

set1.symmetric_difference_update(set2)
print(set3)
# Out:
# {'cherry', 'banana'}
# None
# {'google', 'apple', 'cherry', 'banana', 'microsoft'}
# None

# %%
#dictionary
thisdict = {
    "food":"Dosa",
    "travel":"Delhi",
    "travel":"Jaipur",
    "food2":"Dosa"
}
print(thisdict)

print(thisdict["food"])

print(len(thisdict))
# Out:
# {'food': 'Dosa', 'travel': 'Jaipur', 'food2': 'Dosa'}
# Dosa
# 3

# %%
#construcote
thisdict = dict(name = "radhe", age = "98", coiuntry = "India")
print(thisdict)


#access dictionary item
thisdict = {
    "food":"Dosa",
    "travel":"Delhi",
    "travel":"Jaipur",
    "food2":"Dosa"
}
print(thisdict)

print(thisdict["food"])

#get keys
x = thisdict.keys()
print(x)
thisdict["area"] = "region"
print(x)


#get values
print(thisdict.values())

#get items
print(thisdict.items)
# Out:
# {'name': 'radhe', 'age': '98', 'coiuntry': 'India'}
# {'food': 'Dosa', 'travel': 'Jaipur', 'food2': 'Dosa'}
# Dosa
# dict_keys(['food', 'travel', 'food2'])
# dict_keys(['food', 'travel', 'food2', 'area'])
# dict_values(['Dosa', 'Jaipur', 'Dosa', 'region'])
# <built-in method items of dict object at 0x7d8ee720e500>

# %%
thisdict = {
    "food":"Dosa",
    "travel":"Delhi",
    "travel":"Jaipur",
    "food2":"Dosa"
}
print(thisdict)

for y in thisdict.values():
  print(y)
# Out:
# {'food': 'Dosa', 'travel': 'Jaipur', 'food2': 'Dosa'}
# Dosa
# Jaipur
# Dosa

# %%
p = 100
r =4
n =2
t =2
A = p(1+r/n)**(n*t)
print(A)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3340683273.py in <cell line: 0>()
#       3 n =2
#       4 t =2
# ----> 5 A = p(1+r/n)**(n*t)
#       6 print(A)
#
# TypeError: 'int' object is not callable

# %%
sum of even numbers from 1 to 20
