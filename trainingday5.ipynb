# %% [markdown]
# <a href="https://colab.research.google.com/github/Drat47/Dharmesh-/blob/main/trainingday5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#functions and modules

# %%
#FUUNCTIONSS WITH ARGUMENT

def my_fun(name):
  print(name)

my_fun("Rahm")



def my_fun(name,ending):
  print(name,ending)

my_fun("Rahm","how")
# Out:
# Rahm
# Rahm how

# %%
def my_fun(name,ending):
  print(name,ending +"are"+" "+"you")

my_fun("Rahm","how")
my_fun("Rahm","hoe")


def my_fun(name,ending):
  print(name,ending +"are"+" "+"you")
  return "ohh"

my_fun("Rahm","how")
a = my_fun("Rahm","hoe")
print(a)
# Out:
# Rahm howare you
# Rahm hoeare you
# Rahm howare you
# Rahm hoeare you
# ohh

# %%
def my_fun(name,ending="welcome"):
  print(name,ending +"are"+" "+"you")
  return "ohh"

my_fun("Rahm","how")
my_fun("Rahm")
# Out:
# Rahm howare you
# Rahm welcomeare you
# 'ohh'

# %%
def my_fun(name,ending="welcome"):
  print(f"hello ,{name},{ending}")
  return "ohh"

my_fun("Rahm","how")
my_fun("Rahm")
# Out:
# hello ,Rahm,how
# hello ,Rahm,welcome
# 'ohh'

# %%
#recursion
def fact(n):
  if n ==1 or n ==0:
    return 1
  else:
    return n*fact(n-1)

n = int(input("enter the number :"))
print(f"the fact of {n} is {fact(n)}")
# Out:
# enter the number :5
# the fact of 5 is 120

# %%
#recursion
def fact(n):
  if n ==1 or n ==0:
    return 1
  return n*fact(n-1)

n = int(input("enter the number :"))
print(f"the fact of {n} is {fact(n)}")
# Out:
# enter the number :48
# the fact of 48 is 12413915592536072670862289047373375038521486354677760000000000

# %%
#pass by value like behavioyur(immutable)
def change_number(n):
  n = n+10
  print("value og change is ",n)

n =5
change_number(n)
print("value of n is ",n)
# Out:
# value og change is  15
# value of n is  5

# %%
#pas by reference like behaviour
def modigy_list(lst):
  lst.append(100)
  print("value of list is ",lst)

lst = [1,2,3,4]
print(lst)
modigy_list(lst)
print(" the list is ",lst)
# Out:
# [1, 2, 3, 4]
# value of list is  [1, 2, 3, 4, 100]
#  the list is  [1, 2, 3, 4, 100]

# %%
#positional or required argument
def add(a,b):
  print("sum",a+b)

add(4,3)
# Out:
# sum 7

# %%
#keyword argument
def student(name,age):
  print("name",name)
  print("age",age)

student(age=19,name="rahm")
# Out:
# name rahm
# age 19

# %%
#variable length argumkent
def marks(*marks):
  print("marks",sum(marks))
marks(23,45,12)
# Out:
# marks 80

# %%
#keyword only argument
def greet(*,name,age):
  print(age,name)
greet(name = "dha",age= "234")
# Out:
# 234 dha

# %%
#con=binstion of all
def example(a,b,*args,name = "Guest",**kwargs):
  print(a,b)
  print(args)
  print(name)
  print(kwargs)

example(1,2,3,4,name = "hain",city = "dekgi",age =23)
# Out:
# 1 2
# (3, 4)
# hain
# {'city': 'dekgi', 'age': 23}

# %%
#con=binstion of all
def example(a,b,*args,name = "Guest",**kwargs):
  print(a,b)
  print(args)
  print(name)
  print(kwargs)

example(1,2,3,4,name = "hain",city = "dekgi",age =23)
# Out:
# 1 2
# (3, 4)
# hain
# {'city': 'dekgi', 'age': 23}

# %%
def my_func():
  print("the naem ")

my_func()
my_func()
my_func()
# Out:
# the naem
# the naem
# the naem

# %%
def greet():
  "this is something"#doc string
  '''sdfdsf'''
  print("hello")

greet()
# Out:
# hello

# %%
def greet(str):
  "this is something"
  '''sdfdsf'''
  print("hello")
  return

greet()
# Out:
# hello

# %%
def greet(name):
  "this is something"
  '''sdfdsf'''
  print("hello{}".format(name))
  return

greet("aadi")
greet("fhdgj")
# Out:
# helloaadi
# hellofhdgj

# %%
def greet(name,msg):
  "this is something"
  '''sdfdsf'''
  print("hello{}".format(name),msg)
  return

greet("aadi","dgfdg") # Fixed: Passed two separate arguments
greet(msg= "fhdgj",name = "aad")
# Out:
# helloaadi dgfdg
# helloaad fhdgj

# %%
#return typr
def add(a,b):
    return a+b
def is_true(a):
    return bool(a)

res = add(2,3)
print(res)
print(is_true(res))
# Out:
# 5
# True

# %%
def greet():
  name = "hecl"
  age = 23
  return name,age
name,age =greet()

print("name",name)
print("age",age)
# Out:
# name hecl
# age 23

# %%
def fun(a):
  return(a**2,a**3)
result = fun(a)
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2675353648.py in <cell line: 0>()
#       1 def fun(a):
#       2   return(a**2,a**3)
# ----> 3 result = fun(a)
#       4 print(result)
#
# /tmp/ipython-input-2675353648.py in fun(a)
#       1 def fun(a):
# ----> 2   return(a**2,a**3)
#       3 result = fun(a)
#       4 print(result)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %%
#function under function
def fun1(msg):
  def fun2():
    return f"message{msg}"
  return fun2

fun3 = fun1("hcl")
print(fun3())



def fun1(msg):
  def fun2():
    return f"message{msg}"
  return fun2

fun3 = fun1("hcl")
print(fun3)
# Out:
# messagehcl
# <function fun1.<locals>.fun2 at 0x7855f15634c0>

# %%
#import modules
import math
print(math.sqrt(25))
print(math.pi)
# Out:
# 5.0
# 3.141592653589793

# %%
from math import sqrt, pi
print(sqrt(34))
print(pi)
# Out:
# 5.830951894845301
# 3.141592653589793

# %%
#im;oprt with allias
import math as m
print(m.sqrt(25))
print(m.pi)
# Out:
# 5.0
# 3.141592653589793

# %%
import requests
r = requests.get("https://www.linkedin.com")
print(r.status_code)
# Out:
# 200

# %%
import sys
for p in sys.path:
  print(p)
# Out:
# /content
# /env/python
# /usr/lib/python312.zip
# /usr/lib/python3.12
# /usr/lib/python3.12/lib-dynload
#
# /usr/local/lib/python3.12/dist-packages
# /usr/lib/python3/dist-packages
# /usr/local/lib/python3.12/dist-packages/IPython/extensions
# /root/.ipython

# %%
import webbrowser
r = "https://chatgpt.com/c/69390873-b818-8321-92d5-fed88598237c"
webbrowser.open(r)
# Out:
# False

# %%
import requests
r = requests.get("https://chatgpt.com/c/69390873-b818-8321-92d5-fed88598237c")
print(r.status_code)
# Out:
# 403

# %%
# Given an integer, , perform the following conditional actions:
# •	If  is odd, print Weird
# •	If  is even and in the inclusive range of  to , print Not Weird
# •	If  is even and in the inclusive range of  to , print Weird
# •	If  is even and greater than , print Not Weird
# Input Format
# A single line containing a positive integer, .
# 1<= n <= 100

# Output Format
# Print Weird if the number is weird. Otherwise, print Not Weird.

# Solution:
import math
import os
import random
import re
import sys


if __name__=='__main__':
  n = int(input())
  if n % 2 == 1:
    print("Weird")
  elif n % 2 == 0 and 2 <= n <= 5:
    print("Not Weird")
  elif n % 2 == 0 and 6 <= n <= 20:
    print("Weird")
  elif n % 2 == 0 and n > 20:
    print("Not Weird")
# Out:
# 12
# Weird
