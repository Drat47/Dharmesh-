# %% [markdown]
# <a href="https://colab.research.google.com/github/Drat47/Dharmesh-/blob/main/trainingday8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#tuple
ordred
unchangable iterable
heterogeneous

# %%
#tuples are inder=xed
contain duplicate values
updating anm element
Acees a tuple using apostive index
Acees a tuple using negative index
concatenation in python tuple
traversing each element
slicing in python tuple
deleting a tuple
nesting of tuple
repeatinf of tuple

# %%
tup = ("hecl")*3
print(tup)

tup1 = ("HIii","fii")
tup2 = (12,3)
tup3 = (tup1,tup2)
print(tup3)

tup1 = ("HIii","fii")
tup2 = (12,3)
tup3 = tup1+tup2
print(tup3)
# Out:
# heclheclhecl
# (('HIii', 'fii'), (12, 3))
# ('HIii', 'fii', 12, 3)

# %%
tuples = (1,2,4,4,5)
print(tuples[1:])
print(tuples[-1])
print(tuples[1:3])

del tuples
print(tuples)
# Out:
# (2, 4, 4, 5)
# 5
# (2, 4)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2034850508.py in <cell line: 0>()
#       5
#       6 del tuples
# ----> 7 print(tuples)
#
# NameError: name 'tuples' is not defined

# %%
tuples = (1,2,4,4,5)
print(len(tuples))
print(max(tuples))
print(min(tuples))
print(sum(tuples))
print(sorted(tuples))
# Out:
# 5
# 5
# 1
# 16
# [1, 2, 4, 4, 5]

# %%
#conversion
a = [23,45,23,23,1,34]
tup = tuple(a)
print( tup)
# Out:
# (23, 45, 23, 23, 1, 34)

# %%
#tiples in loop
tup = ("hcll",)
n =5
for i in range(n):
  tup = (tup,)
  print(tup)
# Out:
# (('hcll',),)
# ((('hcll',),),)
# (((('hcll',),),),)
# ((((('hcll',),),),),)
# (((((('hcll',),),),),),)

# %%
#tuple packing
a,b,c = 11,22,34
tup=(a,b,c)
print(tup)
# Out:
# (11, 22, 34)

# %%
tupl1 = ("apple ","fruits")
tupl2 = ("orange",)
tupl1  += tupl2
print(tupl1)
# Out:
# ('apple ', 'fruits', 'orange')

# %%
#unpack
fruits = ("fruits","banana","cherry")
(green,yellow,red) = fruits
print(green)
print(yellow)


fruits = ("fruits","banana","cherry","guava")
(green,*yellow,red) = fruits
print(green)
print(yellow)
# Out:
# fruits
# banana
# fruits
# ['banana', 'cherry']

# %%
tuple1 = ("hcl",23,"hii",23,43,)
print(tuple1)
print(tuple1[3])
print(tuple1[-1])
tuple1[2] = "Rahul"
print(tuple1)
# Out:
# ('hcl', 23, 'hii', 23, 43)
# 23
# 43
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2919770937.py in <cell line: 0>()
#       3 print(tuple1[3])
#       4 print(tuple1[-1])
# ----> 5 tuple1[2] = "Rahul"
#       6 print(tuple1)
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1 = ()
print(type(t1))
t2 = ("hii")
print(type(t2))
# Out:
# <class 'tuple'>
# <class 'str'>

# %%
# #dictionary
# 3.7 version and upper shows ordered

d  = {"name":"Rahul","age":23,
      1 : "hii",
      (1,3) : [1,2,3]}
print(d)
# Out:
# {'name': 'Rahul', 'age': 23, 1: 'hii', (1, 3): [1, 2, 3]}

# %%
d1 = {'name': 'Rahul', 'age': 23, 1: 'hii', (1, 3): [1, 2, 3]}
d1["age"] = 45
d1[1] = "python dict"
print(d1)
# Out:
# {'name': 'Rahul', 'age': 45, 1: 'python dict', (1, 3): [1, 2, 3]}

# %%
d1 = {'name': 'Rahul', 'age': 23, 1: 'hii', (1, 3): [1, 2, 3]}
del d1["age"]
print(d1)
# Out:
# {'name': 'Rahul', 1: 'hii', (1, 3): [1, 2, 3]}

# %%
dv = {}
print(type(dv))
# Out:
# <class 'dict'>

# %%
fruits ={
    'apple' = 230,
    'cherry' = 23
}

print(fruits)
# Out:
#   File "/tmp/ipython-input-1585672456.py", line 2
#     'apple' = 230,
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
#zip method = to combine the dictionary
fruits = {"Apple","Cherry","Lichi"}
fruits2 = {123,3453,123,543,556}
fruits3 = dict(zip(fruits,fruits2))
print(fruits3)
# Out:
# {'Lichi': 123, 'Apple': 556, 'Cherry': 3453}

# %%
name = {"Dharmesh"}
freq = {}
for i in name:
  if i not in freq:
    freq[i] = 1
  else:
    freq[i] += 1
print(freq)



from collections import Counter
name="prince jain"
print(Counter(name))
# Out:
# {'Dharmesh': 1}

# %%
#stack
push,pop,peek,isEmpty,size operations

# %%
d1 = {'name': 'Rahul', 'age': 23, 1: 'hii', (1, 3): [1, 2, 3]}
val = d1.pop(1)
print(val)
# Out:
# hii

# %%
d1 = {'name': 'Rahul', 'age': 23, 1: 'hii', (1, 3): [1, 2, 3]}

key , val = d.popitem()
print(f"key:{key}, value : {val}")
d1.clear()
print(d1)
# Out:
# key:age, value : 23
# {}

# %%
#nested dictionay
d = {1:"hoo",
     2:"hello",
     3:{'3.3':"yee", 5 : "jey"}}

print(d)
# Out:
# {1: 'hoo', 2: 'hello', 3: {'3.3': 'yee', 5: 'jey'}}

# %%
#cosntructoe
thisdict = dict(name = "rahul",age = "35")
print(thisdict)
# Out:
# {'name': 'rahul', 'age': '35'}

# %%
#pop item
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
a = thisdict.pop("brand")
print(a)
# Out:
# Ford

# %%
dict_list = [{"name":"rahul", "age":"23"},
         {"name":"raj","age":"45"}
]
for c in dict_list:
  print(c)
# Out:
# {'name': 'rahul', 'age': '23'}
# {'name': 'raj', 'age': '45'}

# %%
#to fetch both key and values
dict2 = {"name":"rhaul","age":23}
for x,y in dict2.items():
  print(x,y)
# Out:
# name rhaul
# age 23

# %%
#COPY A dict
dict2 = {"name":"rhaul","age":23}
mydict = dict2.copy()
print(mydict)
# Out:
# {'name': 'rhaul', 'age': 23}

# %%
#nested directory
myfamily = {
    "company" : {
        "name": "rahul",
        "age" : 23
    },
    "company2" : {
        "name" : "rahul",
        "age" :"23"
    },
    "company3 ": {
        "name" : "rahul",
        "age" : 23
    }
    }
print(myfamily["company"]["name"])
# Out:
# rahul

# %%
myfamily = {
    "company" : {
        "name": "rahul",
        "age" : 23
    },
    "company2" : {
        "name" : "rahul",
        "age" :"23"
    },
    "company3 ": {
        "name" : "rahul",
        "age" : 23
    }
    }


    #using for loop priting the list
